# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load data
df = pd.read_csv("/content/smart_meter_data.csv") # Assuming the file is uploaded to the Colab session or in the current working directory

# %% [markdown]
# explore data

# %%
df.head()
# Out:
#              Timestamp  Electricity_Consumed  Temperature  Humidity  \
# 0  2024-01-01 00:00:00              0.457786     0.469524  0.396368
# 1  2024-01-01 00:30:00              0.351956     0.465545  0.451184
# 2  2024-01-01 01:00:00              0.482948     0.285415  0.408289
# 3  2024-01-01 01:30:00              0.628838     0.482095  0.512308
# 4  2024-01-01 02:00:00              0.335974     0.624741  0.672021
#
#    Wind_Speed  Avg_Past_Consumption Anomaly_Label
# 0    0.445441              0.692057        Normal
# 1    0.458729              0.539874        Normal
# 2    0.470360              0.614724        Normal
# 3    0.576241              0.757044        Normal
# 4    0.373004              0.673981        Normal

# %%
df.shape
# Out:
# (5000, 7)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Electricity_Consumed', 'Temperature', 'Humidity',
#        'Wind_Speed', 'Avg_Past_Consumption', 'Anomaly_Label'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Timestamp             5000 non-null   object
#  1   Electricity_Consumed  5000 non-null   float64
#  2   Temperature           5000 non-null   float64
#  3   Humidity              5000 non-null   float64
#  4   Wind_Speed            5000 non-null   float64
#  5   Avg_Past_Consumption  5000 non-null   float64
#  6   Anomaly_Label         5000 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#        Electricity_Consumed  Temperature     Humidity   Wind_Speed  \
# count           5000.000000  5000.000000  5000.000000  5000.000000
# mean               0.376677     0.525069     0.497632     0.464628
# std                0.164117     0.135603     0.146781     0.120370
# min                0.000000     0.000000     0.000000     0.000000
# 25%                0.265349     0.434253     0.398956     0.382906
# 50%                0.377244     0.524052     0.497539     0.464958
# 75%                0.486002     0.617281     0.595359     0.547419
# max                1.000000     1.000000     1.000000     1.000000
#
#        Avg_Past_Consumption
# count           5000.000000
# mean               0.458738
# std                0.146749
# min                0.000000
# 25%                0.358857
# 50%                0.457814
# 75%                0.555607
# max                1.000000

# %% [markdown]
# Data quality check

# %%
df.isnull().sum()
# Out:
# Timestamp               0
# Electricity_Consumed    0
# Temperature             0
# Humidity                0
# Wind_Speed              0
# Avg_Past_Consumption    0
# Anomaly_Label           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#no missing value & duplicated

# %% [markdown]
# analysis

# %%
df.mean(numeric_only=True)
# Out:
# Electricity_Consumed    0.376677
# Temperature             0.525069
# Humidity                0.497632
# Wind_Speed              0.464628
# Avg_Past_Consumption    0.458738
# dtype: float64

# %%
print("Max:", df['Electricity_Consumed'].max())
print("Min:", df['Electricity_Consumed'].min())
print("Mean:", df['Electricity_Consumed'].mean())
# Out:
# Max: 1.0
# Min: 0.0
# Mean: 0.37667745005931613

# %%
df['Anomaly_Label'].value_counts()
# Out:
# Anomaly_Label
# Normal      4750
# Abnormal     250
# Name: count, dtype: int64

# %%
#الداتا مش متوازنة الموديل هيبصمج

# %%
df.groupby('Anomaly_Label')['Electricity_Consumed'].mean()
# Out:
# Anomaly_Label
# Abnormal    0.379039
# Normal      0.376553
# Name: Electricity_Consumed, dtype: float64

# %% [markdown]
# Data Visualization

# %% [markdown]
# Countplot

# %%
sns.countplot(x=df['Anomaly_Label'])
plt.title("Normal vs Anomaly Count")
plt.show()

# %%
#dataset is imbalanced (Normal >> Abnormal)

# %%
#هيبصمج بصمجة قوية خلوا بالكم

# %% [markdown]
# Histogram

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Electricity_Consumed'], bins=30)
plt.title("Distribution of Electricity Consumption")
plt.xlabel("Consumption")
plt.ylabel("Frequency")
plt.show()

# %%
# اغلب الناس ف الداتا استهلاكها متوسط بس عندنا شوية حرامية ف الاطراف

# %% [markdown]
# Boxplot to find outlier

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df['Electricity_Consumed'])
plt.title("Boxplot of Electricity Consumption")
plt.show()

# %%
#There are outliers in electricity consumption indicating abnormal behavior

# %%
#عندنا شوية نقط بعيد عن الاستهلاك الطبيعي يعني شوية سرقة عايزين الموديل يكتشفها

# %% [markdown]
# Heatmap

# %%
plt.figure(figsize=(10,6))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Scatter

# %%
sns.scatterplot(x=df['Avg_Past_Consumption'], y=df['Electricity_Consumed'], hue=df['Anomaly_Label'])
plt.title("Current vs Past Consumption")
plt.show()

# %%
#Some records don't follow the expected relationship between past and current consumption

# %%
#في استهلاك اتغير بجنون

# %% [markdown]
# Time plot

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df = df.sort_values('Timestamp')

plt.figure(figsize=(12,5))
plt.plot(df['Timestamp'], df['Electricity_Consumed'])
plt.title("Electricity Consumption Over Time")
plt.xlabel("Time")
plt.ylabel("Consumption")
plt.show()

# %%
#هنا بنشوف الاستهلاك بيتغير ازاي بمرور الوقت

# %%
#drop & spike غالبا سرقة

# %% [markdown]
#  Prepare feature matrix and target column for the next stage

# %%
X = df[['Electricity_Consumed', 'Temperature', 'Humidity', 'Wind_Speed', 'Avg_Past_Consumption']]
y = df['Anomaly_Label']

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
print(X.head())
print(y.head())
# Out:
# X shape: (5000, 5)
# y shape: (5000,)
#    Electricity_Consumed  Temperature  Humidity  Wind_Speed  \
# 0              0.457786     0.469524  0.396368    0.445441
# 1              0.351956     0.465545  0.451184    0.458729
# 2              0.482948     0.285415  0.408289    0.470360
# 3              0.628838     0.482095  0.512308    0.576241
# 4              0.335974     0.624741  0.672021    0.373004
#
#    Avg_Past_Consumption
# 0              0.692057
# 1              0.539874
# 2              0.614724
# 3              0.757044
# 4              0.673981
# 0    Normal
# 1    Normal
# 2    Normal
# 3    Normal
# 4    Normal
# Name: Anomaly_Label, dtype: object

# %% [markdown]
# **Note:**
#
# The dataset is imbalanced (Normal > Abnormal)  ▶  (للتأكيد )

# %% [markdown]
# **Data preparation**

# %%
# Convert from string to datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# Sort data by time for LSTM to ensure correct sequence learning
df = df.sort_values('Timestamp')

df.head()
# Out:
#             Timestamp  Electricity_Consumed  Temperature  Humidity  \
# 0 2024-01-01 00:00:00              0.457786     0.469524  0.396368
# 1 2024-01-01 00:30:00              0.351956     0.465545  0.451184
# 2 2024-01-01 01:00:00              0.482948     0.285415  0.408289
# 3 2024-01-01 01:30:00              0.628838     0.482095  0.512308
# 4 2024-01-01 02:00:00              0.335974     0.624741  0.672021
#
#    Wind_Speed  Avg_Past_Consumption Anomaly_Label
# 0    0.445441              0.692057        Normal
# 1    0.458729              0.539874        Normal
# 2    0.470360              0.614724        Normal
# 3    0.576241              0.757044        Normal
# 4    0.373004              0.673981        Normal

# %% [markdown]
# **Label Encoding**

# %%
# Convert labels to numeric
df['Anomaly_Label'] = df['Anomaly_Label'].map({
    'Normal': 0,
    'Abnormal': 1
})

df['Anomaly_Label'].value_counts()
#  Normal = 0 , Theft = 1
# Out:
# Anomaly_Label
# 0    4750
# 1     250
# Name: count, dtype: int64

# %% [markdown]
# **Feature Engineering**

# %%
# Create new feature: difference between current and past consumption that will directly capture abnormal behavior
df['Consumption_Diff'] = (
    df['Electricity_Consumed'] - df['Avg_Past_Consumption']
)

df.head()
# Out:
#             Timestamp  Electricity_Consumed  Temperature  Humidity  \
# 0 2024-01-01 00:00:00              0.457786     0.469524  0.396368
# 1 2024-01-01 00:30:00              0.351956     0.465545  0.451184
# 2 2024-01-01 01:00:00              0.482948     0.285415  0.408289
# 3 2024-01-01 01:30:00              0.628838     0.482095  0.512308
# 4 2024-01-01 02:00:00              0.335974     0.624741  0.672021
#
#    Wind_Speed  Avg_Past_Consumption  Anomaly_Label  Consumption_Diff
# 0    0.445441              0.692057              0         -0.234272
# 1    0.458729              0.539874              0         -0.187918
# 2    0.470360              0.614724              0         -0.131776
# 3    0.576241              0.757044              0         -0.128206
# 4    0.373004              0.673981              0         -0.338007

# %%
# Positive values -- ((theft) spike)
# Negative values -- (potential drop)

# %% [markdown]
# **Feature Scaling**
# (normalizing using MinMaxScaler)

# %%
# Used MinMaxScaler because input should be in a small bounded range because LSTM uses: Sigmoid activation -- outputs between (0,1) ,Tanh activation -- outputs between (-1,1)
# any other scaler will lead to unstable results

# %%
from sklearn.preprocessing import MinMaxScaler

features = [
    'Electricity_Consumed',
    'Temperature',
    'Humidity',
    'Wind_Speed',
    'Avg_Past_Consumption',
    'Consumption_Diff'
]

scaler = MinMaxScaler()

df[features] = scaler.fit_transform(df[features])

df.head()
# Out:
#             Timestamp  Electricity_Consumed  Temperature  Humidity  \
# 0 2024-01-01 00:00:00              0.457786     0.469524  0.396368
# 1 2024-01-01 00:30:00              0.351956     0.465545  0.451184
# 2 2024-01-01 01:00:00              0.482948     0.285415  0.408289
# 3 2024-01-01 01:30:00              0.628838     0.482095  0.512308
# 4 2024-01-01 02:00:00              0.335974     0.624741  0.672021
#
#    Wind_Speed  Avg_Past_Consumption  Anomaly_Label  Consumption_Diff
# 0    0.445441              0.692057              0          0.336864
# 1    0.458729              0.539874              0          0.373827
# 2    0.470360              0.614724              0          0.418596
# 3    0.576241              0.757044              0          0.421443
# 4    0.373004              0.673981              0          0.254144

# %% [markdown]
# **Train/Test Split**

# %%
# Split based on time
split = int(0.8 * len(df))

train_df = df.iloc[:split]
test_df = df.iloc[split:]

print("Train size:", len(train_df))
print("Test size:", len(test_df))
# To Prevents data leakage
# Out:
# Train size: 4000
# Test size: 1000

# %% [markdown]
# **Applying SMOTE on training data only**

# %%
from imblearn.over_sampling import SMOTE

X_train = train_df[features]
y_train = train_df['Anomaly_Label']

# Apply SMOTE ONLY on training data
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

print("Before SMOTE:\n", y_train.value_counts())
print("\nAfter SMOTE:\n", pd.Series(y_train_resampled).value_counts())
# Out:
# Before SMOTE:
#  Anomaly_Label
# 0    3805
# 1     195
# Name: count, dtype: int64
#
# After SMOTE:
#  Anomaly_Label
# 0    3805
# 1    3805
# Name: count, dtype: int64

# %%
# Model learns:Patterns from balanced training data
#Then tested on: Real world data (test set Represents real world data, Still imbalanced (like reality))
# So the accuracy is honest

# %% [markdown]
# **Prepare Test Data**
#  (nothing changed)

# %%
# Test data must remain realistic
X_test = test_df[features]
y_test = test_df['Anomaly_Label']

# %% [markdown]
# **Converts data → sequences**

# %%
# LSTM learns patterns over time from sequences
def create_sequences(X, y, time_steps=10):
    X_seq, y_seq = [], []

    for i in range(len(X) - time_steps):
        X_seq.append(X[i:i+time_steps])
        y_seq.append(y[i+time_steps])

    return np.array(X_seq), np.array(y_seq)

# %% [markdown]
# **Apply Sequence Creation**

# %%
time_steps = 10

# Training sequences
X_train_seq, y_train_seq = create_sequences(
    X_train_resampled.values,
    y_train_resampled.values,
    time_steps
)

# Testing sequences
X_test_seq, y_test_seq = create_sequences(
    X_test.values,
    y_test.values,
    time_steps
)

print("Train shape:", X_train_seq.shape)
print("Test shape:", X_test_seq.shape)
# Out:
# Train shape: (7600, 10, 6)
# Test shape: (990, 10, 6)

# %%
df.head()
# Out:
#             Timestamp  Electricity_Consumed  Temperature  Humidity  \
# 0 2024-01-01 00:00:00              0.457786     0.469524  0.396368
# 1 2024-01-01 00:30:00              0.351956     0.465545  0.451184
# 2 2024-01-01 01:00:00              0.482948     0.285415  0.408289
# 3 2024-01-01 01:30:00              0.628838     0.482095  0.512308
# 4 2024-01-01 02:00:00              0.335974     0.624741  0.672021
#
#    Wind_Speed  Avg_Past_Consumption  Anomaly_Label  Consumption_Diff
# 0    0.445441              0.692057              0          0.336864
# 1    0.458729              0.539874              0          0.373827
# 2    0.470360              0.614724              0          0.418596
# 3    0.576241              0.757044              0          0.421443
# 4    0.373004              0.673981              0          0.254144

# %%
#  Save TRAIN data (after SMOTE + sequences)


# Flatten sequences to 2D for saving
X_train_flat = X_train_seq.reshape(X_train_seq.shape[0], -1)

train_df_final = pd.DataFrame(X_train_flat)
train_df_final['Target'] = y_train_seq

train_df_final.to_csv("train_data_lstm.csv", index=False)


# Save TEST data (original sequences)


X_test_flat = X_test_seq.reshape(X_test_seq.shape[0], -1)

test_df_final = pd.DataFrame(X_test_flat)
test_df_final['Target'] = y_test_seq

test_df_final.to_csv("test_data_lstm.csv", index=False)


#  Save MERGED data (train + test)


merged_df = pd.concat([train_df_final, test_df_final], axis=0)

merged_df.to_csv("merged_data_lstm.csv", index=False)


print("Files saved successfully:")
print("- train_data_lstm.csv")
print("- test_data_lstm.csv")
print("- merged_data_lstm.csv")
# Out:
# Files saved successfully:
# - train_data_lstm.csv
# - test_data_lstm.csv
# - merged_data_lstm.csv

# %% [markdown]
# # **Model Training**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.utils import class_weight

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Input

lstm_model = Sequential()

lstm_model.add(Input(shape=(X_train_seq.shape[1], X_train_seq.shape[2])))

lstm_model.add(LSTM(256, return_sequences=True))
lstm_model.add(Dropout(0.3))

lstm_model.add(LSTM(64, return_sequences=True))
lstm_model.add(Dropout(0.3))

lstm_model.add(LSTM(32))
lstm_model.add(Dropout(0.3))

lstm_model.add(Dense(1, activation='sigmoid'))

lstm_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
y_prob = lstm_model.predict(X_test_seq)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step

# %%
y_prob = y_prob.reshape(-1)
print(y_prob[:20])
# Out:
# [0.5120201  0.51205176 0.51202685 0.51161087 0.51130337 0.5107101
#  0.5105395  0.5105741  0.5106342  0.5105996  0.5103207  0.5106834
#  0.51068896 0.5109475  0.5110959  0.51114625 0.5109763  0.51070786
#  0.5105966  0.51068383]

# %%
# Callbacks

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3
)

# %%
# Train model
history = lstm_model.fit(
    X_train_seq,
    y_train_seq,
    epochs=24,
    batch_size=32,
    validation_data=(X_test_seq, y_test_seq),
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.5363 - loss: 0.6833 - val_accuracy: 0.0556 - val_loss: 0.7718 - learning_rate: 0.0010
# Epoch 2/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - accuracy: 0.5768 - loss: 0.6551 - val_accuracy: 0.9010 - val_loss: 0.5259 - learning_rate: 0.0010
# Epoch 3/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - accuracy: 0.8642 - loss: 0.3090 - val_accuracy: 0.9444 - val_loss: 0.2156 - learning_rate: 0.0010
# Epoch 4/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 14s 61ms/step - accuracy: 0.9675 - loss: 0.1199 - val_accuracy: 0.9444 - val_loss: 0.2059 - learning_rate: 0.0010
# Epoch 5/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9711 - loss: 0.1097 - val_accuracy: 0.9444 - val_loss: 0.2057 - learning_rate: 0.0010
# Epoch 6/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.9688 - loss: 0.1164 - val_accuracy: 0.9444 - val_loss: 0.2100 - learning_rate: 0.0010
# Epoch 7/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - accuracy: 0.9729 - loss: 0.1068 - val_accuracy: 0.9444 - val_loss: 0.1968 - learning_rate: 0.0010
# Epoch 8/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.9718 - loss: 0.1060 - val_accuracy: 0.9384 - val_loss: 0.2189 - learning_rate: 0.0010
# Epoch 9/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9707 - loss: 0.1064 - val_accuracy: 0.9444 - val_loss: 0.1976 - learning_rate: 0.0010
# Epoch 10/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - accuracy: 0.9720 - loss: 0.1023 - val_accuracy: 0.9444 - val_loss: 0.2082 - learning_rate: 0.0010
# Epoch 11/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 28s 84ms/step - accuracy: 0.9743 - loss: 0.0911 - val_accuracy: 0.9414 - val_loss: 0.2066 - learning_rate: 2.0000e-04
# Epoch 12/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.9739 - loss: 0.0904 - val_accuracy: 0.9444 - val_loss: 0.1864 - learning_rate: 2.0000e-04
# Epoch 13/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.9738 - loss: 0.0882 - val_accuracy: 0.9444 - val_loss: 0.1888 - learning_rate: 2.0000e-04
# Epoch 14/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - accuracy: 0.9739 - loss: 0.0900 - val_accuracy: 0.9444 - val_loss: 0.1903 - learning_rate: 2.0000e-04
# Epoch 15/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - accuracy: 0.9742 - loss: 0.0879 - val_accuracy: 0.9444 - val_loss: 0.2055 - learning_rate: 2.0000e-04
# Epoch 16/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9742 - loss: 0.0853 - val_accuracy: 0.9414 - val_loss: 0.1824 - learning_rate: 4.0000e-05
# Epoch 17/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.9754 - loss: 0.0852 - val_accuracy: 0.9414 - val_loss: 0.1866 - learning_rate: 4.0000e-05
# Epoch 18/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.9749 - loss: 0.0856 - val_accuracy: 0.9444 - val_loss: 0.1879 - learning_rate: 4.0000e-05
# Epoch 19/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.9762 - loss: 0.0864 - val_accuracy: 0.9424 - val_loss: 0.1827 - learning_rate: 4.0000e-05
# Epoch 20/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.9755 - loss: 0.0846 - val_accuracy: 0.9404 - val_loss: 0.1840 - learning_rate: 8.0000e-06
# Epoch 21/24
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 13s 53ms/step - accuracy: 0.9759 - loss: 0.0838 - val_accuracy: 0.9424 - val_loss: 0.1835 - learning_rate: 8.0000e-06

# %%
#  Plot Loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title("Loss Curve")
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, f1_score

y_prob = lstm_model.predict(X_test_seq)

precision, recall, pr_thresholds = precision_recall_curve(y_test_seq, y_prob)

f1_scores = []

for t in pr_thresholds:
    y_pred = (y_prob > t).astype(int)
    f1_scores.append(f1_score(y_test_seq, y_pred))

best_idx = np.argmax(f1_scores)
best_threshold_pr = pr_thresholds[best_idx]

print("Best Threshold (PR):", best_threshold_pr)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Best Threshold (PR): 0.10628819

# %%
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, roc_thresholds = roc_curve(y_test_seq, y_prob)

optimal_idx = np.argmax(tpr - fpr)
best_threshold_roc = roc_thresholds[optimal_idx]

roc_auc = roc_auc_score(y_test_seq, y_prob)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}")
plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
#  Combine ALL thresholds

thresholds_to_test = [
    0.5, 0.4, 0.3, 0.2, 0.1, 0.08, 0.075, 0.05,
    best_threshold_pr,
    best_threshold_roc
]

# إزالة التكرار
#thresholds_to_test = list(set(thresholds_to_test))

# ترتيبهم
#thresholds_to_test.sort(reverse=True)

# Evaluation Loop

for t in thresholds_to_test:
    y_pred = (y_prob > t).astype(int)

    print(f"\n🔹 Threshold = {t}")
    print(classification_report(y_test_seq, y_pred))
# Out:
# 🔹 Threshold = 0.5
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       935
#            1       0.29      0.04      0.06        55
#
#     accuracy                           0.94       990
#    macro avg       0.62      0.52      0.52       990
# weighted avg       0.91      0.94      0.92       990
#
#
# 🔹 Threshold = 0.4
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       935
#            1       0.43      0.11      0.17        55
#
#     accuracy                           0.94       990
#    macro avg       0.69      0.55      0.57       990
# weighted avg       0.92      0.94      0.93       990
#
#
# 🔹 Threshold = 0.3
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       935
#            1       0.32      0.15      0.20        55
#
#     accuracy                           0.94       990
#    macro avg       0.64      0.56      0.58       990
# weighted avg       0.92      0.94      0.92       990
#
#
# 🔹 Threshold = 0.2
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       935
#            1       0.29      0.25      0.27        55
#
#     accuracy                           0.92       990
#    macro avg       0.62      0.61      0.62       990
# weighted avg       0.92      0.92      0.92       990
#
#
# 🔹 Threshold = 0.1
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       935
#            1       0.28      0.45      0.34        55
#
#     accuracy                           0.90       990
#    macro avg       0.62      0.69      0.65       990
# weighted avg       0.93      0.90      0.91       990
#
#
# 🔹 Threshold = 0.08
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94       935
#            1       0.26      0.51      0.34        55
#
#     accuracy                           0.89       990
#    macro avg       0.61      0.71      0.64       990
# weighted avg       0.93      0.89      0.91       990
#
#
# 🔹 Threshold = 0.075
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94       935
#            1       0.25      0.51      0.34        55
#
#     accuracy                           0.89       990
#    macro avg       0.61      0.71      0.64       990
# weighted avg       0.93      0.89      0.91       990
#
#
# 🔹 Threshold = 0.05
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.91       935
#            1       0.21      0.64      0.32        55
#
#     accuracy                           0.85       990
#    macro avg       0.59      0.75      0.62       990
# weighted avg       0.93      0.85      0.88       990
#
#
# 🔹 Threshold = 0.10628818720579147
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95       935
#            1       0.30      0.45      0.36        55
#
#     accuracy                           0.91       990
#    macro avg       0.64      0.70      0.66       990
# weighted avg       0.93      0.91      0.92       990
#
#
# 🔹 Threshold = 0.03626497834920883
#               precision    recall  f1-score   support
#
#            0       0.98      0.81      0.88       935
#            1       0.18      0.73      0.29        55
#
#     accuracy                           0.80       990
#    macro avg       0.58      0.77      0.59       990
# weighted avg       0.94      0.80      0.85       990

# %%
# تثبيت threshold لانه افضل واحد عمل توازن ما بين التصنيفين
threshold = 0.075

# تحويل probabilities إلى predictions
y_pred = (y_prob > threshold).astype(int)

#  Evaluation

print("Classification Report:\n")
print(classification_report(y_test_seq, y_pred))

print("Confusion Matrix:\n")
cm = confusion_matrix(y_test_seq, y_pred)
print(cm)

sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC AUC
roc = roc_auc_score(y_test_seq, y_prob)
print("ROC AUC:", roc)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94       935
#            1       0.25      0.51      0.34        55
#
#     accuracy                           0.89       990
#    macro avg       0.61      0.71      0.64       990
# weighted avg       0.93      0.89      0.91       990
#
# Confusion Matrix:
#
# [[851  84]
#  [ 27  28]]
# ROC AUC: 0.7893631502187652

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test_seq, y_prob)

plt.figure(figsize=(6,5))
plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(y_prob[y_test_seq == 0], bins=30, alpha=0.6, label="Normal (0)")
plt.hist(y_prob[y_test_seq == 1], bins=30, alpha=0.6, label="Theft (1)")

plt.axvline(x=0.075, color='red', linestyle='--', label="Threshold = 0.075")

plt.title("Probability Distribution")
plt.xlabel("Predicted Probability")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %% [markdown]
# # **Random forest**

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

import seaborn as sns
import matplotlib.pyplot as plt

features = [
    'Electricity_Consumed',
    'Temperature',
    'Humidity',
    'Wind_Speed',
    'Avg_Past_Consumption',
    'Consumption_Diff'
]

X = df[features]
y = df['Anomaly_Label']

split = int(0.8 * len(df))

X_train = X.iloc[:split]
X_test = X.iloc[split:]

y_train = y.iloc[:split]
y_test = y.iloc[split:]

rf_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=10,
    class_weight={0:1, 1:8},
    random_state=42
)

rf_model.fit(X_train, y_train)

y_prob = rf_model.predict_proba(X_test)[:, 1]

thresholds = [0.5, 0.3, 0.2, 0.1, 0.08, 0.075]

for t in thresholds:
    y_pred = (y_prob > t).astype(int)

    print(f"\nThreshold = {t}")
    print(classification_report(y_test, y_pred))

best_threshold = 0.1
y_pred = (y_prob > best_threshold).astype(int)

print("\nFinal Evaluation:")
print(classification_report(y_test, y_pred))

print("ROC AUC:", roc_auc_score(y_test, y_prob))

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title(f"Confusion Matrix (threshold={best_threshold})")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Threshold = 0.5
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       945
#            1       0.96      0.84      0.89        55
#
#     accuracy                           0.99      1000
#    macro avg       0.97      0.92      0.94      1000
# weighted avg       0.99      0.99      0.99      1000
#
#
# Threshold = 0.3
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       945
#            1       0.91      0.96      0.94        55
#
#     accuracy                           0.99      1000
#    macro avg       0.96      0.98      0.97      1000
# weighted avg       0.99      0.99      0.99      1000
#
#
# Threshold = 0.2
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       945
#            1       0.86      0.98      0.92        55
#
#     accuracy                           0.99      1000
#    macro avg       0.93      0.99      0.95      1000
# weighted avg       0.99      0.99      0.99      1000
#
#
# Threshold = 0.1
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       945
#            1       0.74      1.00      0.85        55
#
#     accuracy                           0.98      1000
#    macro avg       0.87      0.99      0.92      1000
# weighted avg       0.99      0.98      0.98      1000
#
#
# Threshold = 0.08
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99       945
#            1       0.68      1.00      0.81        55
#
#     accuracy                           0.97      1000
#    macro avg       0.84      0.99      0.90      1000
# weighted avg       0.98      0.97      0.98      1000
#
#
# Threshold = 0.075
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98       945
#            1       0.66      1.00      0.80        55
#
#     accuracy                           0.97      1000
#    macro avg       0.83      0.99      0.89      1000
# weighted avg       0.98      0.97      0.97      1000
#
#
# Final Evaluation:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       945
#            1       0.74      1.00      0.85        55
#
#     accuracy                           0.98      1000
#    macro avg       0.87      0.99      0.92      1000
# weighted avg       0.99      0.98      0.98      1000
#
# ROC AUC: 0.9987686387686389

# %%
#حساب الـ probabilities  .ravel()→ بتحول الناتج من شكل (matrix) لشكل array 1D
# [[0.1], [0.2]] تبقى [0.1, 0.2]عني بدل
lstm_prob = lstm_model.predict(X_test_seq).ravel()
#predict_proba→ بيرجع احتمال كل class (0 و 1)
#[:, 1]→ بناخد بس احتمال الـ class = 1(anomaly)
rf_prob = rf_model.predict_proba(X_test)[:, 1]
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
# Expert System (Decision Layer)
# الهدف:
# تحويل outputs من LSTM و Random Forest إلى قرار نهائي مفهوم

def expert_system(lstm_p, rf_p,
                  lstm_threshold=0.075,
                  rf_threshold=0.3):

    # 1) حالة الاتفاق التام (Normal)
    # لو الاتنين أقل من threshold
    if lstm_p < lstm_threshold and rf_p < rf_threshold:
        return {
            "final_model": "Both Models",
            "status": "Normal",
            "risk": "Low",
            "probability": float(max(lstm_p, rf_p)),
            "agreement": "Full Agreement (Normal)",
            "reason": "Both LSTM and Random Forest detect normal consumption"
        }

    # 2) تحديد النموذج الأكثر ثقة

    # LSTM أقوى بشكل واضح
    if lstm_p > rf_p + 0.2:
        chosen_model = "LSTM"
        prob = lstm_p
        threshold = lstm_threshold

    # Random Forest أقوى بشكل واضح
    elif rf_p > lstm_p + 0.2:
        chosen_model = "Random Forest"
        prob = rf_p
        threshold = rf_threshold

    # الفرق بسيط
    else:
        chosen_model = "LSTM" if lstm_p >= rf_p else "Random Forest"
        prob = max(lstm_p, rf_p)
        threshold = lstm_threshold if chosen_model == "LSTM" else rf_threshold

    # 3) تحويل الاحتمال إلى مستوى خطر

    if prob < threshold:
        status = "Normal"
        risk = "Low"

    elif prob < 0.5:
        status = "Suspicious"
        risk = "Medium"

    elif prob < 0.9:
        status = "Anomaly"
        risk = "High"

    else:
        status = "Critical"
        risk = "Very High"

    # 4) حساب درجة الاتفاق بين النموذجين
    agreement_score = 1 - abs(lstm_p - rf_p)

    # 5) إخراج النتيجة النهائية
    return {
        "final_model": chosen_model,
        "lstm_prob": float(lstm_p),
        "rf_prob": float(rf_p),
        "probability": float(prob),
        "status": status,
        "risk": risk,
        "agreement_score": float(agreement_score),
        "agreement": "High" if agreement_score > 0.8 else "Low",
        "reason": f"Decision based on {chosen_model} with threshold logic"
    }

# %%
# تطبيق الـ Expert System على كل بيانات الاختبار
# الهدف:
# تحويل كل زوج (LSTM probability + RF probability)
# إلى قرار نهائي (Normal / Suspicious / Anomaly / Critical)

# ليست فاضية هنخزن فيها نتائج كل sample
results = []

# loop على كل sample في الداتا
for i in range(len(lstm_prob)):

    # ندي لكل sample احتمالاته
    result = expert_system(
        lstm_prob[i],
        rf_prob[i]
    )

    # تخزين النتيجة النهائية في list
    results.append(result)

# %%
#عدد كل حالة
import pandas as pd

df_results = pd.DataFrame(results, columns=['status'])
df_results['status'].value_counts()
# Out:
# status
# Normal        833
# Suspicious    104
# Anomaly        48
# Critical        5
# Name: count, dtype: int64

# %%
#هوزع المخاطر
import pandas as pd

df_results = pd.DataFrame(results, columns=['risk'])
df_results['risk'].value_counts()
# Out:
# risk
# Low          833
# Medium       104
# High          48
# Very High      5
# Name: count, dtype: int64

# %%
import pandas as pd

# إنشاء df_results بحيث يحتوي على كل الأعمدة المطلوبة
df_results = pd.DataFrame(results, columns=['status'])

# إضافة الأعمدة الناقصة عشان الكود الأصلي يشتغل
df_results['risk'] = 'Unknown'
df_results['final_model'] = 'Unknown'

# %%
#  Create Comparison Table
# مقارنة نتائج LSTM و Random Forest مع قرار الـ Expert System النهائي

# أولاً: لتأكد إن كل القوائم بنفس الطول
n = min(len(lstm_prob), len(rf_prob), len(df_results))

# بناء DataFrame للمقارنة
comparison = pd.DataFrame({
    # احتمال LSTM لكل عينة
    "LSTM_Probability": lstm_prob[:n],

    # احتمال Random Forest لكل عينة
    "RF_Probability": rf_prob[:n],

    # القرار النهائي من الـ Expert System
    "Final_Status": df_results['status'][:n],

    # مستوى الخطورة
    "Risk_Level": df_results['risk'][:n],

    # الموديل المستخدم في القرار
    "Chosen_Model": df_results['final_model'][:n]
})

# عرض أول 5 صفوف
comparison.head()
# Out:
#    LSTM_Probability  RF_Probability Final_Status Risk_Level Chosen_Model
# 0          0.030834        0.004550       Normal    Unknown      Unknown
# 1          0.025213        0.001915       Normal    Unknown      Unknown
# 2          0.032598        0.000900       Normal    Unknown      Unknown
# 3          0.040097        0.001294       Normal    Unknown      Unknown
# 4          0.088800        0.012663   Suspicious    Unknown      Unknown

# %%
import pandas as pd

# التأكد إن كل القوائم بنفس الطول
n = min(len(lstm_prob), len(rf_prob), len(df_results))

# إنشاء جدول المقارنة بين LSTM و Random Forest ونتائج الـ Expert System
comparison = pd.DataFrame({
    "LSTM_Probability": lstm_prob[:n],   # احتمال LSTM
    "RF_Probability": rf_prob[:n],       # احتمال Random Forest
    "Final_Status": df_results['status'][:n],  # القرار النهائي من الـ Expert System
    "Risk_Level": df_results['risk'][:n],      # مستوى الخطورة
    "Chosen_Model": df_results['final_model'][:n]  # الموديل الذي تم اختياره
})

# حساب الفرق بين توقعات LSTM و RF لمعرفة مدى الاختلاف بينهم
comparison["Model_Difference"] = abs(
    comparison["LSTM_Probability"] - comparison["RF_Probability"]
)

# قياس درجة اتفاق الموديلات (كلما زادت القيمة يعني توافق أعلى)
comparison["Model_Agreement"] = comparison["LSTM_Probability"] * comparison["RF_Probability"]

# عرض عينة عشوائية من النتائج لتمثيل كل الحالات (Normal / Anomaly / Critical)
comparison.sample(10)
# Out:
#      LSTM_Probability  RF_Probability Final_Status Risk_Level Chosen_Model  \
# 670          0.014601        0.003476       Normal    Unknown      Unknown
# 516          0.015934        0.000775       Normal    Unknown      Unknown
# 629          0.226991        0.000516   Suspicious    Unknown      Unknown
# 836          0.013637        0.000771       Normal    Unknown      Unknown
# 706          0.017526        0.001730       Normal    Unknown      Unknown
# 179          0.014704        0.000864       Normal    Unknown      Unknown
# 70           0.158896        0.001742   Suspicious    Unknown      Unknown
# 157          0.029075        0.001504       Normal    Unknown      Unknown
# 837          0.014413        0.002469       Normal    Unknown      Unknown
# 454          0.014419        0.001842       Normal    Unknown      Unknown
#
#      Model_Difference  Model_Agreement
# 670          0.011125         0.000051
# 516          0.015159         0.000012
# 629          0.226475         0.000117
# 836          0.012866         0.000011
# 706          0.015797         0.000030
# 179          0.013841         0.000013
# 70           0.157154         0.000277
# 157          0.027572         0.000044
# 837          0.011945         0.000036
# 454          0.012577         0.000027

# %%
import matplotlib.pyplot as plt

comparison["Final_Status"].value_counts().plot(kind="bar")
plt.title("Final System Decisions Distribution")
plt.xlabel("Status")
plt.ylabel("Count")
plt.show()

# %%
comparison["Risk_Level"].value_counts().plot(kind="bar")
plt.title("Risk Level Distribution")
plt.xlabel("Risk Level")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(comparison["Model_Difference"], bins=30)
plt.title("Difference Between LSTM and RF Predictions")
plt.xlabel("Difference")
plt.ylabel("Frequency")
plt.show()

# %%
import random
import time
import pandas as pd

# عدد العينات اللي عايزين نولدها
num_samples = 1000

data = []

for i in range(num_samples):

    # -----------------------------
    # 1. توليد القيم الطبيعية
    # -----------------------------
    base_consumption = random.uniform(2, 4)

    # نقرر هل دي anomaly ولا لا
    is_anomaly = random.random() < 0.1  # 10% anomalies

    if is_anomaly:
        # استهلاك غير طبيعي (سرقة أو spike)
        consumption = random.uniform(6, 10)
    else:
        consumption = base_consumption

    temperature = random.uniform(20, 35)
    humidity = random.uniform(30, 70)
    wind_speed = random.uniform(0, 10)

    avg_past = base_consumption + random.uniform(-0.5, 0.5)

    consumption_diff = consumption - avg_past

    # -----------------------------
    # 2. حفظ البيانات
    # -----------------------------
    data.append([
        consumption,
        temperature,
        humidity,
        wind_speed,
        avg_past,
        consumption_diff,
        int(is_anomaly)
    ])

# -----------------------------
# 3. تحويل لـ DataFrame
# -----------------------------
df_sim = pd.DataFrame(data, columns=[
    'Electricity_Consumed',
    'Temperature',
    'Humidity',
    'Wind_Speed',
    'Avg_Past_Consumption',
    'Consumption_Diff',
    'Anomaly_Label'
])

# -----------------------------
# 4. حفظ الملف
# -----------------------------
df_sim.to_csv("simulated_data.csv", index=False)

print("Simulation Done ✅")
df_sim.head()
# Out:
# Simulation Done ✅
#    Electricity_Consumed  Temperature   Humidity  Wind_Speed  \
# 0              3.915289    20.206694  62.145472    7.527741
# 1              8.468489    23.944836  64.878766    3.509956
# 2              3.731446    21.132982  31.802828    6.821954
# 3              3.484808    34.178636  59.870990    5.620663
# 4              2.896020    21.911638  51.487050    5.503490
#
#    Avg_Past_Consumption  Consumption_Diff  Anomaly_Label
# 0              3.471683          0.443606              0
# 1              2.322483          6.146006              1
# 2              3.537834          0.193612              0
# 3              3.454083          0.030725              0
# 4              3.149891         -0.253871              0

# %%
import random
import time

while True:
    consumption = random.uniform(2, 4)

    if random.random() < 0.1:
        consumption = random.uniform(6, 10)  # anomaly

    print(f"Consumption: {consumption:.2f}")

    time.sleep(1)
# Out:
# Consumption: 3.57
# Consumption: 3.63
# Consumption: 3.32
# Consumption: 3.76
# Consumption: 2.57
# Consumption: 3.29
# Consumption: 3.98
# Consumption: 7.30
# Consumption: 2.76
# Consumption: 2.09
# Consumption: 3.78
# Consumption: 2.91
# Consumption: 3.68
# Consumption: 2.28
# Consumption: 9.08
# Consumption: 3.41
# Consumption: 3.01
# Consumption: 2.13
# Consumption: 8.53
# Consumption: 3.63
# Consumption: 3.65
# Consumption: 2.22
# Consumption: 2.82
# Consumption: 2.34
# Consumption: 9.94
# Consumption: 3.51
# Consumption: 2.62
# Consumption: 2.13
# Consumption: 3.05
# Consumption: 3.90
# Consumption: 2.73
# Consumption: 3.55
# Consumption: 2.43
# Consumption: 3.61
# Consumption: 2.59
# Consumption: 3.11
# Consumption: 3.17
# Consumption: 2.07
# Consumption: 2.77
# Consumption: 3.05
# Consumption: 3.84
# Consumption: 2.64
# Consumption: 3.12
# Consumption: 2.55
# Consumption: 7.13
# Consumption: 3.29
# Consumption: 2.91
# Consumption: 3.87
# Consumption: 3.00
# Consumption: 3.29
# Consumption: 3.20
# Consumption: 3.51
# Consumption: 3.75
# Consumption: 2.87
# Consumption: 3.12
# Consumption: 3.18
# Consumption: 3.04
# Consumption: 3.36
# Consumption: 2.23
# Consumption: 4.00
# Consumption: 3.66
# Consumption: 3.29
# Consumption: 3.17
# Consumption: 2.67
# Consumption: 9.48
# Consumption: 2.84
# Consumption: 2.49
# Consumption: 3.26
# Consumption: 2.16
# Consumption: 2.25
# Consumption: 2.60
# Consumption: 2.58
# Consumption: 2.53
# Consumption: 2.60
# Consumption: 6.87
# Consumption: 2.97
# Consumption: 8.36
# Consumption: 8.52
# Consumption: 2.06
# Consumption: 3.60
# Consumption: 2.57
# Consumption: 3.82
# Consumption: 6.19
# Consumption: 3.18
# Consumption: 2.37
# Consumption: 2.30
# Consumption: 2.71
# Consumption: 2.63
# Consumption: 2.86
# Consumption: 2.29
# Consumption: 3.43
# Consumption: 2.52
# Consumption: 2.32
# Consumption: 2.38
# Consumption: 2.65
# Consumption: 8.05
# Consumption: 2.95
# Consumption: 3.61
# Consumption: 2.53
# Consumption: 7.00
# Consumption: 3.72
# Consumption: 3.46
# Consumption: 3.92
# Consumption: 3.47
# Consumption: 2.74
# Consumption: 2.88
# Consumption: 2.19
# Consumption: 2.04
# Consumption: 2.14
# Consumption: 2.87
# Consumption: 3.89
# Consumption: 2.28
# Consumption: 2.15
# Consumption: 2.63
# Consumption: 3.77
# Consumption: 2.89
# Consumption: 8.60
# Consumption: 2.72
# Consumption: 3.11
# Consumption: 3.23
# Consumption: 3.99
# Consumption: 3.35
# Consumption: 3.98
# Consumption: 3.32
# Consumption: 2.61
# Consumption: 3.76
# Consumption: 2.14
# Consumption: 2.75
# Consumption: 7.02
# Consumption: 2.73
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4956/3836512337.py in <cell line: 0>()
#      10     print(f"Consumption: {consumption:.2f}")
#      11
# ---> 12     time.sleep(1)
#
# KeyboardInterrupt:

# %%
import random
import time

running = True

try:
    while running:

        consumption = random.uniform(2, 4)

        if random.random() < 0.1:
            consumption = random.uniform(6, 10)

        temperature = random.uniform(20, 35)
        humidity = random.uniform(30, 70)
        wind_speed = random.uniform(0, 10)
        avg_past = random.uniform(2, 4)

        consumption_diff = consumption - avg_past

        sample = {
            'Electricity_Consumed': consumption,
            'Temperature': temperature,
            'Humidity': humidity,
            'Wind_Speed': wind_speed,
            'Avg_Past_Consumption': avg_past,
            'Consumption_Diff': consumption_diff
        }
#كل ثانية sample جديد
        print(sample)

        time.sleep(1)

except KeyboardInterrupt:
    print("🛑 Simulation Stopped by User")
# Out:
# {'Electricity_Consumed': 3.018646780355267, 'Temperature': 34.06089275776227, 'Humidity': 62.73729525335288, 'Wind_Speed': 8.618741529876967, 'Avg_Past_Consumption': 3.570514105684099, 'Consumption_Diff': -0.551867325328832}
# {'Electricity_Consumed': 3.0220878044513277, 'Temperature': 31.961146044662257, 'Humidity': 57.53674531501134, 'Wind_Speed': 9.376667948439668, 'Avg_Past_Consumption': 3.4931178688662303, 'Consumption_Diff': -0.4710300644149026}
# {'Electricity_Consumed': 2.2183847959717626, 'Temperature': 25.267395148247303, 'Humidity': 33.35629294308211, 'Wind_Speed': 6.3601094469161366, 'Avg_Past_Consumption': 3.846127604406573, 'Consumption_Diff': -1.6277428084348102}
# {'Electricity_Consumed': 3.806258134485006, 'Temperature': 20.725470608615705, 'Humidity': 60.60117672046582, 'Wind_Speed': 8.79071113002592, 'Avg_Past_Consumption': 2.031687331001089, 'Consumption_Diff': 1.774570803483917}
# {'Electricity_Consumed': 2.712572469971179, 'Temperature': 26.363837321171673, 'Humidity': 52.12905854025982, 'Wind_Speed': 4.183003927395297, 'Avg_Past_Consumption': 3.4021182202975977, 'Consumption_Diff': -0.6895457503264186}
# {'Electricity_Consumed': 2.25408380307419, 'Temperature': 30.115699586235323, 'Humidity': 57.07428623813536, 'Wind_Speed': 4.855092234036457, 'Avg_Past_Consumption': 2.7090168191804898, 'Consumption_Diff': -0.4549330161062999}
# {'Electricity_Consumed': 2.4818236665994826, 'Temperature': 23.94017140691423, 'Humidity': 38.285968097758705, 'Wind_Speed': 6.595551779147217, 'Avg_Past_Consumption': 2.519558733912538, 'Consumption_Diff': -0.037735067313055204}
# {'Electricity_Consumed': 8.43496856797935, 'Temperature': 25.48639202319788, 'Humidity': 44.4609968585966, 'Wind_Speed': 8.808578388468742, 'Avg_Past_Consumption': 3.0658410379201886, 'Consumption_Diff': 5.369127530059162}
# {'Electricity_Consumed': 3.544148469321972, 'Temperature': 25.763357053201023, 'Humidity': 64.24561979167754, 'Wind_Speed': 9.488570768415723, 'Avg_Past_Consumption': 3.933783442915958, 'Consumption_Diff': -0.38963497359398636}
# {'Electricity_Consumed': 2.5725223596944016, 'Temperature': 34.88338849719708, 'Humidity': 54.05788503089907, 'Wind_Speed': 7.031137828937304, 'Avg_Past_Consumption': 3.092280943844992, 'Consumption_Diff': -0.5197585841505905}
# {'Electricity_Consumed': 6.9053283824625105, 'Temperature': 24.846217275074512, 'Humidity': 56.01073053675702, 'Wind_Speed': 5.918057306442175, 'Avg_Past_Consumption': 2.6254556455714924, 'Consumption_Diff': 4.2798727368910185}
# {'Electricity_Consumed': 3.4942401146105526, 'Temperature': 29.675587965249214, 'Humidity': 66.50986758901942, 'Wind_Speed': 5.227477642841976, 'Avg_Past_Consumption': 2.468400735889097, 'Consumption_Diff': 1.0258393787214555}
# {'Electricity_Consumed': 2.0385888319437226, 'Temperature': 34.491706186365896, 'Humidity': 32.18486833255798, 'Wind_Speed': 9.990689777930713, 'Avg_Past_Consumption': 2.1976819431490027, 'Consumption_Diff': -0.15909311120528002}
# {'Electricity_Consumed': 2.347797278209431, 'Temperature': 24.290591183407997, 'Humidity': 61.126733667518224, 'Wind_Speed': 5.708295402287852, 'Avg_Past_Consumption': 2.069194064566707, 'Consumption_Diff': 0.2786032136427239}
# {'Electricity_Consumed': 3.8880875396905346, 'Temperature': 34.42657360765068, 'Humidity': 64.17605112147092, 'Wind_Speed': 1.1774467980863934, 'Avg_Past_Consumption': 3.294728029686495, 'Consumption_Diff': 0.5933595100040394}
# {'Electricity_Consumed': 3.7412075286096624, 'Temperature': 30.029862253770812, 'Humidity': 58.92053381194532, 'Wind_Speed': 3.1874594458086536, 'Avg_Past_Consumption': 3.2784035519038595, 'Consumption_Diff': 0.462803976705803}
# {'Electricity_Consumed': 2.5980590781431516, 'Temperature': 34.68423195787209, 'Humidity': 63.70120063749556, 'Wind_Speed': 2.9369812818856733, 'Avg_Past_Consumption': 3.69886606751731, 'Consumption_Diff': -1.1008069893741586}
# {'Electricity_Consumed': 2.1005213260110978, 'Temperature': 20.646149709499237, 'Humidity': 43.503772905570514, 'Wind_Speed': 4.606772349246296, 'Avg_Past_Consumption': 2.93849431758025, 'Consumption_Diff': -0.8379729915691523}
# {'Electricity_Consumed': 3.8011591680317114, 'Temperature': 33.31063340656384, 'Humidity': 57.69322607585713, 'Wind_Speed': 9.027340717691235, 'Avg_Past_Consumption': 2.577378520362074, 'Consumption_Diff': 1.2237806476696376}
# {'Electricity_Consumed': 3.27131820393794, 'Temperature': 25.31471298432936, 'Humidity': 49.284142114024355, 'Wind_Speed': 9.116561213281324, 'Avg_Past_Consumption': 3.3012552740210106, 'Consumption_Diff': -0.029937070083070783}
# {'Electricity_Consumed': 2.645540864252445, 'Temperature': 25.882086157239232, 'Humidity': 45.11826085612171, 'Wind_Speed': 1.5559832304092247, 'Avg_Past_Consumption': 3.6314599960451694, 'Consumption_Diff': -0.9859191317927243}
# {'Electricity_Consumed': 3.2239327972134086, 'Temperature': 32.29231699599175, 'Humidity': 54.56664009971463, 'Wind_Speed': 8.379472007775657, 'Avg_Past_Consumption': 2.5809446697068172, 'Consumption_Diff': 0.6429881275065914}
# {'Electricity_Consumed': 3.18565167582428, 'Temperature': 28.297875149070883, 'Humidity': 51.232513018465866, 'Wind_Speed': 9.632422198008895, 'Avg_Past_Consumption': 3.150847763864556, 'Consumption_Diff': 0.03480391195972432}
# {'Electricity_Consumed': 2.350298010792536, 'Temperature': 30.6578544689308, 'Humidity': 44.62076309127267, 'Wind_Speed': 0.9514761048732656, 'Avg_Past_Consumption': 2.5117017872542844, 'Consumption_Diff': -0.1614037764617482}
# {'Electricity_Consumed': 3.465700002604874, 'Temperature': 32.55633236125249, 'Humidity': 38.11229392470021, 'Wind_Speed': 8.275148847445298, 'Avg_Past_Consumption': 2.9517303454167076, 'Consumption_Diff': 0.5139696571881665}
# {'Electricity_Consumed': 7.090431093758571, 'Temperature': 34.212044868223344, 'Humidity': 51.13374089084958, 'Wind_Speed': 2.9872999569863348, 'Avg_Past_Consumption': 3.8138376047219817, 'Consumption_Diff': 3.2765934890365895}
# {'Electricity_Consumed': 3.7090771738731805, 'Temperature': 30.909959257403848, 'Humidity': 45.76659519836331, 'Wind_Speed': 7.161948052841712, 'Avg_Past_Consumption': 3.042861023167351, 'Consumption_Diff': 0.6662161507058295}
# {'Electricity_Consumed': 3.714020371441795, 'Temperature': 22.683005657709067, 'Humidity': 67.93410972406602, 'Wind_Speed': 8.68367765960664, 'Avg_Past_Consumption': 3.5576052860683243, 'Consumption_Diff': 0.15641508537347093}
# {'Electricity_Consumed': 3.5661851830672933, 'Temperature': 27.096303764496874, 'Humidity': 59.30824272764084, 'Wind_Speed': 2.998832821423325, 'Avg_Past_Consumption': 2.7384906418259374, 'Consumption_Diff': 0.8276945412413559}
# {'Electricity_Consumed': 2.893919341913136, 'Temperature': 34.192272884824064, 'Humidity': 59.99881752695038, 'Wind_Speed': 2.5343867186785527, 'Avg_Past_Consumption': 3.229894020899673, 'Consumption_Diff': -0.335974678986537}
# {'Electricity_Consumed': 2.7924811481392453, 'Temperature': 22.982419721550613, 'Humidity': 53.57368838041565, 'Wind_Speed': 5.50425460376616, 'Avg_Past_Consumption': 2.481891333772316, 'Consumption_Diff': 0.31058981436692923}
# {'Electricity_Consumed': 9.3064551991282, 'Temperature': 31.659992492501033, 'Humidity': 49.43661455099899, 'Wind_Speed': 8.473584611662249, 'Avg_Past_Consumption': 3.6019523693842954, 'Consumption_Diff': 5.704502829743904}
# {'Electricity_Consumed': 6.73383041301428, 'Temperature': 29.87319541930326, 'Humidity': 59.10027185206781, 'Wind_Speed': 6.432444344348499, 'Avg_Past_Consumption': 3.6542392127690055, 'Consumption_Diff': 3.0795912002452743}
# {'Electricity_Consumed': 2.208415077587034, 'Temperature': 27.177286627241315, 'Humidity': 56.64589574758928, 'Wind_Speed': 4.8810038635509585, 'Avg_Past_Consumption': 2.3692787300776645, 'Consumption_Diff': -0.1608636524906304}
# {'Electricity_Consumed': 2.8067762925467417, 'Temperature': 21.995686418681508, 'Humidity': 68.43235326367822, 'Wind_Speed': 2.725490985664586, 'Avg_Past_Consumption': 2.970854095786065, 'Consumption_Diff': -0.1640778032393233}
# {'Electricity_Consumed': 3.4735088383815063, 'Temperature': 20.552225406034694, 'Humidity': 63.05916137615155, 'Wind_Speed': 9.751706850178156, 'Avg_Past_Consumption': 2.7683336204983884, 'Consumption_Diff': 0.7051752178831179}
# {'Electricity_Consumed': 3.7904060840572944, 'Temperature': 23.22608914037811, 'Humidity': 65.24230678202318, 'Wind_Speed': 2.071673918456658, 'Avg_Past_Consumption': 2.4241132329094173, 'Consumption_Diff': 1.3662928511478771}
# {'Electricity_Consumed': 2.2040865144595254, 'Temperature': 26.652361545259673, 'Humidity': 55.814092026187666, 'Wind_Speed': 2.7779583062035442, 'Avg_Past_Consumption': 3.855668039245124, 'Consumption_Diff': -1.6515815247855987}
# {'Electricity_Consumed': 7.700544573795552, 'Temperature': 30.436890273026435, 'Humidity': 45.0252644749612, 'Wind_Speed': 7.91838193901686, 'Avg_Past_Consumption': 3.36046211907364, 'Consumption_Diff': 4.340082454721912}
# {'Electricity_Consumed': 2.649369053316356, 'Temperature': 30.06804368359184, 'Humidity': 37.23457035323528, 'Wind_Speed': 2.009968315684212, 'Avg_Past_Consumption': 2.155568143493506, 'Consumption_Diff': 0.49380090982284974}
# {'Electricity_Consumed': 2.2235462152685463, 'Temperature': 29.88651030958792, 'Humidity': 61.378121169656126, 'Wind_Speed': 1.3006946090885296, 'Avg_Past_Consumption': 2.4847160850328853, 'Consumption_Diff': -0.261169869764339}
# {'Electricity_Consumed': 3.0516016610508743, 'Temperature': 23.371902721544057, 'Humidity': 46.53738124227219, 'Wind_Speed': 1.4791792983470609, 'Avg_Past_Consumption': 3.9161361808588047, 'Consumption_Diff': -0.8645345198079304}
# {'Electricity_Consumed': 2.857378688569762, 'Temperature': 23.471772674660002, 'Humidity': 61.891381871530626, 'Wind_Speed': 5.996008392152095, 'Avg_Past_Consumption': 3.5983044794903507, 'Consumption_Diff': -0.7409257909205889}
# {'Electricity_Consumed': 3.120266713698427, 'Temperature': 20.356758769540892, 'Humidity': 60.39934435267429, 'Wind_Speed': 4.960310412897005, 'Avg_Past_Consumption': 2.726810270269307, 'Consumption_Diff': 0.3934564434291201}
# {'Electricity_Consumed': 2.6820288495132623, 'Temperature': 28.109975657069697, 'Humidity': 31.079037784866014, 'Wind_Speed': 7.793066393400983, 'Avg_Past_Consumption': 3.3988494619022696, 'Consumption_Diff': -0.7168206123890073}
# {'Electricity_Consumed': 2.4022373039804785, 'Temperature': 24.138886315507406, 'Humidity': 68.42837078219935, 'Wind_Speed': 8.778824740018697, 'Avg_Past_Consumption': 3.8556176931033477, 'Consumption_Diff': -1.4533803891228692}
# {'Electricity_Consumed': 3.157500019894621, 'Temperature': 20.06479075250036, 'Humidity': 37.878309827686095, 'Wind_Speed': 1.107682424959534, 'Avg_Past_Consumption': 3.9876097602633496, 'Consumption_Diff': -0.8301097403687288}
# {'Electricity_Consumed': 3.8034684806814782, 'Temperature': 32.65002889836097, 'Humidity': 39.41605319836851, 'Wind_Speed': 7.36186147933374, 'Avg_Past_Consumption': 3.078705339975088, 'Consumption_Diff': 0.7247631407063904}
# {'Electricity_Consumed': 3.17384326850271, 'Temperature': 23.098580726549805, 'Humidity': 34.48206128405235, 'Wind_Speed': 9.082742670052994, 'Avg_Past_Consumption': 3.9016495579662926, 'Consumption_Diff': -0.7278062894635826}
# {'Electricity_Consumed': 3.5579011608371243, 'Temperature': 29.824600816428656, 'Humidity': 56.97071523932851, 'Wind_Speed': 0.7851935956399636, 'Avg_Past_Consumption': 2.3846427487088873, 'Consumption_Diff': 1.173258412128237}
# {'Electricity_Consumed': 2.205692084645485, 'Temperature': 20.99630710821846, 'Humidity': 34.15958745144549, 'Wind_Speed': 3.815434548717165, 'Avg_Past_Consumption': 2.1477137833916586, 'Consumption_Diff': 0.05797830125382619}
# 🛑 Simulation Stopped by User

# %%
import joblib
from google.colab import files
import inspect
from datetime import datetime

model = rf_model

# إنشاء timestamp عشان كل مرة يبقى اسم مختلف
timestamp = datetime.now().strftime("%Y%m%d_%H%M")

# أسماء مميزة للفايلات
lstm_filename = f"powerguard_LSTM_v1_{timestamp}.keras"
rf_filename = f"powerguard_RF_v1_{timestamp}.pkl"
results_filename = f"powerguard_results_v1_{timestamp}.csv"
expert_filename = f"powerguard_expert_v1_{timestamp}.py"

# حفظ موديل LSTM
lstm_model.save(lstm_filename)

# حفظ موديل Random Forest
joblib.dump(model, rf_filename)

# حفظ النتائج (اختياري)
df_results.to_csv(results_filename, index=False)

# حفظ كود الـ Expert System
with open(expert_filename, "w") as f:
    f.write(inspect.getsource(expert_system))

# تحميل الملفات
files.download(lstm_filename)
files.download(rf_filename)
files.download(results_filename)
files.download(expert_filename)

print("Files saved with unique names ✅")
print(lstm_filename)
print(rf_filename)
print(results_filename)
print(expert_filename)
# Out:
# Files saved with unique names ✅
# powerguard_LSTM_v1_20260504_2140.keras
# powerguard_RF_v1_20260504_2140.pkl
# powerguard_results_v1_20260504_2140.csv
# powerguard_expert_v1_20260504_2140.py

# %%
import random
import time

def generate_sample():
    """Generate one simulated smart meter reading"""

    consumption = random.uniform(2, 4)

    # simulate anomaly
    if random.random() < 0.1:
        consumption = random.uniform(6, 10)

    temperature = random.uniform(20, 35)
    humidity = random.uniform(30, 70)
    wind_speed = random.uniform(0, 10)
    avg_past = random.uniform(2, 4)

    consumption_diff = consumption - avg_past

    return {
        'Electricity_Consumed': round(consumption, 2),
        'Temperature': round(temperature, 2),
        'Humidity': round(humidity, 2),
        'Wind_Speed': round(wind_speed, 2),
        'Avg_Past_Consumption': round(avg_past, 2),
        'Consumption_Diff': round(consumption_diff, 2)
    }


# =========================
# Simulation Control
# =========================
running = True

print("⚡ Simulation Started... (Press CTRL + C to stop)\n")

try:
    while running:

        sample = generate_sample()

        # =========================
        # SIMPLE RULE-BASED ACTION (Expert-like behavior)
        # =========================
        if sample["Electricity_Consumed"] > 7:
            status = "🚨 ANOMALY"
            action = "Send Alert"
        elif sample["Electricity_Consumed"] > 5:
            status = "⚠️ Suspicious"
            action = "Monitor"
        else:
            status = "✅ Normal"
            action = "No Action"

        # =========================
        # OUTPUT
        # =========================
        print("\n=========================")
        print("📊 Sample Data:", sample)
        print("📌 Status:", status)
        print("⚙️ Action:", action)
        print("=========================")

        time.sleep(1)

except KeyboardInterrupt:
    running = False
    print("\n🛑 Simulation Stopped by User")
# Out:
# ⚡ Simulation Started... (Press CTRL + C to stop)
#
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.97, 'Temperature': 27.47, 'Humidity': 69.12, 'Wind_Speed': 1.74, 'Avg_Past_Consumption': 2.89, 'Consumption_Diff': 0.08}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.14, 'Temperature': 28.4, 'Humidity': 44.21, 'Wind_Speed': 6.25, 'Avg_Past_Consumption': 2.18, 'Consumption_Diff': -0.04}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 7.35, 'Temperature': 25.91, 'Humidity': 57.33, 'Wind_Speed': 1.3, 'Avg_Past_Consumption': 3.92, 'Consumption_Diff': 3.43}
# 📌 Status: 🚨 ANOMALY
# ⚙️ Action: Send Alert
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.58, 'Temperature': 31.88, 'Humidity': 53.46, 'Wind_Speed': 1.12, 'Avg_Past_Consumption': 2.07, 'Consumption_Diff': 1.51}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.75, 'Temperature': 31.28, 'Humidity': 48.71, 'Wind_Speed': 3.36, 'Avg_Past_Consumption': 2.7, 'Consumption_Diff': 0.05}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.72, 'Temperature': 30.89, 'Humidity': 64.97, 'Wind_Speed': 3.52, 'Avg_Past_Consumption': 2.79, 'Consumption_Diff': 0.93}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.23, 'Temperature': 34.33, 'Humidity': 58.36, 'Wind_Speed': 0.21, 'Avg_Past_Consumption': 2.74, 'Consumption_Diff': -0.51}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.58, 'Temperature': 31.49, 'Humidity': 45.94, 'Wind_Speed': 9.01, 'Avg_Past_Consumption': 3.52, 'Consumption_Diff': 0.06}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.99, 'Temperature': 24.65, 'Humidity': 68.62, 'Wind_Speed': 2.27, 'Avg_Past_Consumption': 3.33, 'Consumption_Diff': 0.66}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.38, 'Temperature': 30.56, 'Humidity': 47.77, 'Wind_Speed': 8.02, 'Avg_Past_Consumption': 3.15, 'Consumption_Diff': 0.23}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.27, 'Temperature': 21.93, 'Humidity': 32.81, 'Wind_Speed': 1.4, 'Avg_Past_Consumption': 2.67, 'Consumption_Diff': -0.4}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.76, 'Temperature': 34.66, 'Humidity': 31.41, 'Wind_Speed': 6.69, 'Avg_Past_Consumption': 3.67, 'Consumption_Diff': -0.91}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 9.16, 'Temperature': 33.16, 'Humidity': 68.63, 'Wind_Speed': 5.22, 'Avg_Past_Consumption': 3.72, 'Consumption_Diff': 5.45}
# 📌 Status: 🚨 ANOMALY
# ⚙️ Action: Send Alert
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.05, 'Temperature': 29.3, 'Humidity': 48.54, 'Wind_Speed': 4.47, 'Avg_Past_Consumption': 2.6, 'Consumption_Diff': 0.45}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.99, 'Temperature': 30.54, 'Humidity': 61.98, 'Wind_Speed': 1.8, 'Avg_Past_Consumption': 2.09, 'Consumption_Diff': 0.9}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.3, 'Temperature': 27.71, 'Humidity': 56.27, 'Wind_Speed': 5.98, 'Avg_Past_Consumption': 3.58, 'Consumption_Diff': -0.28}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.1, 'Temperature': 27.57, 'Humidity': 68.93, 'Wind_Speed': 0.07, 'Avg_Past_Consumption': 3.77, 'Consumption_Diff': -0.66}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.03, 'Temperature': 22.81, 'Humidity': 54.95, 'Wind_Speed': 6.89, 'Avg_Past_Consumption': 3.04, 'Consumption_Diff': -1.01}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.38, 'Temperature': 23.04, 'Humidity': 39.58, 'Wind_Speed': 1.69, 'Avg_Past_Consumption': 3.63, 'Consumption_Diff': -0.24}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 7.51, 'Temperature': 31.28, 'Humidity': 62.9, 'Wind_Speed': 3.42, 'Avg_Past_Consumption': 3.17, 'Consumption_Diff': 4.34}
# 📌 Status: 🚨 ANOMALY
# ⚙️ Action: Send Alert
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.38, 'Temperature': 30.59, 'Humidity': 35.68, 'Wind_Speed': 5.87, 'Avg_Past_Consumption': 2.66, 'Consumption_Diff': -0.28}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.18, 'Temperature': 22.62, 'Humidity': 61.28, 'Wind_Speed': 8.54, 'Avg_Past_Consumption': 3.66, 'Consumption_Diff': -0.48}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.12, 'Temperature': 31.49, 'Humidity': 52.77, 'Wind_Speed': 4.62, 'Avg_Past_Consumption': 3.93, 'Consumption_Diff': -1.81}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.82, 'Temperature': 30.88, 'Humidity': 67.04, 'Wind_Speed': 5.6, 'Avg_Past_Consumption': 2.33, 'Consumption_Diff': 0.49}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.64, 'Temperature': 24.63, 'Humidity': 32.81, 'Wind_Speed': 7.97, 'Avg_Past_Consumption': 2.06, 'Consumption_Diff': 1.58}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.16, 'Temperature': 26.5, 'Humidity': 45.37, 'Wind_Speed': 7.92, 'Avg_Past_Consumption': 2.48, 'Consumption_Diff': 0.68}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.41, 'Temperature': 24.35, 'Humidity': 63.0, 'Wind_Speed': 2.31, 'Avg_Past_Consumption': 3.56, 'Consumption_Diff': -0.16}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.23, 'Temperature': 30.55, 'Humidity': 46.96, 'Wind_Speed': 2.94, 'Avg_Past_Consumption': 3.63, 'Consumption_Diff': -1.4}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.24, 'Temperature': 27.95, 'Humidity': 62.33, 'Wind_Speed': 6.78, 'Avg_Past_Consumption': 2.83, 'Consumption_Diff': -0.59}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.07, 'Temperature': 22.71, 'Humidity': 55.35, 'Wind_Speed': 6.9, 'Avg_Past_Consumption': 2.38, 'Consumption_Diff': -0.31}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.92, 'Temperature': 29.66, 'Humidity': 60.3, 'Wind_Speed': 0.9, 'Avg_Past_Consumption': 3.53, 'Consumption_Diff': -0.62}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.22, 'Temperature': 31.45, 'Humidity': 50.97, 'Wind_Speed': 1.64, 'Avg_Past_Consumption': 3.09, 'Consumption_Diff': 0.12}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.66, 'Temperature': 22.11, 'Humidity': 51.18, 'Wind_Speed': 5.08, 'Avg_Past_Consumption': 2.63, 'Consumption_Diff': 0.03}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.13, 'Temperature': 30.61, 'Humidity': 48.71, 'Wind_Speed': 6.88, 'Avg_Past_Consumption': 3.38, 'Consumption_Diff': -0.25}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.44, 'Temperature': 28.47, 'Humidity': 33.33, 'Wind_Speed': 0.78, 'Avg_Past_Consumption': 2.9, 'Consumption_Diff': 0.53}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.18, 'Temperature': 34.36, 'Humidity': 66.29, 'Wind_Speed': 9.29, 'Avg_Past_Consumption': 2.16, 'Consumption_Diff': 0.02}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.21, 'Temperature': 25.95, 'Humidity': 37.62, 'Wind_Speed': 4.03, 'Avg_Past_Consumption': 2.58, 'Consumption_Diff': 0.63}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.68, 'Temperature': 33.61, 'Humidity': 59.7, 'Wind_Speed': 6.52, 'Avg_Past_Consumption': 3.65, 'Consumption_Diff': 0.02}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.47, 'Temperature': 33.73, 'Humidity': 49.99, 'Wind_Speed': 7.74, 'Avg_Past_Consumption': 3.34, 'Consumption_Diff': -0.87}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.18, 'Temperature': 31.95, 'Humidity': 57.42, 'Wind_Speed': 0.59, 'Avg_Past_Consumption': 3.08, 'Consumption_Diff': -0.9}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.49, 'Temperature': 32.42, 'Humidity': 66.19, 'Wind_Speed': 3.15, 'Avg_Past_Consumption': 2.04, 'Consumption_Diff': 0.45}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.42, 'Temperature': 32.84, 'Humidity': 59.14, 'Wind_Speed': 9.07, 'Avg_Past_Consumption': 2.89, 'Consumption_Diff': 0.52}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.06, 'Temperature': 34.06, 'Humidity': 30.63, 'Wind_Speed': 2.37, 'Avg_Past_Consumption': 2.44, 'Consumption_Diff': -0.38}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.2, 'Temperature': 22.55, 'Humidity': 65.97, 'Wind_Speed': 5.8, 'Avg_Past_Consumption': 2.12, 'Consumption_Diff': 0.07}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.49, 'Temperature': 33.14, 'Humidity': 36.61, 'Wind_Speed': 9.75, 'Avg_Past_Consumption': 2.71, 'Consumption_Diff': 0.78}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.7, 'Temperature': 29.3, 'Humidity': 52.89, 'Wind_Speed': 0.94, 'Avg_Past_Consumption': 2.47, 'Consumption_Diff': 1.23}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.55, 'Temperature': 23.72, 'Humidity': 37.2, 'Wind_Speed': 1.71, 'Avg_Past_Consumption': 2.58, 'Consumption_Diff': 0.97}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.32, 'Temperature': 23.16, 'Humidity': 68.51, 'Wind_Speed': 4.16, 'Avg_Past_Consumption': 3.46, 'Consumption_Diff': -1.14}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.09, 'Temperature': 32.18, 'Humidity': 60.03, 'Wind_Speed': 4.61, 'Avg_Past_Consumption': 3.49, 'Consumption_Diff': -1.4}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.0, 'Temperature': 31.38, 'Humidity': 59.93, 'Wind_Speed': 6.65, 'Avg_Past_Consumption': 3.78, 'Consumption_Diff': -1.78}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.43, 'Temperature': 20.82, 'Humidity': 40.17, 'Wind_Speed': 5.77, 'Avg_Past_Consumption': 3.02, 'Consumption_Diff': -0.59}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 7.48, 'Temperature': 30.91, 'Humidity': 58.01, 'Wind_Speed': 2.19, 'Avg_Past_Consumption': 3.45, 'Consumption_Diff': 4.03}
# 📌 Status: 🚨 ANOMALY
# ⚙️ Action: Send Alert
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.49, 'Temperature': 23.45, 'Humidity': 68.41, 'Wind_Speed': 0.55, 'Avg_Past_Consumption': 2.63, 'Consumption_Diff': -0.14}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.97, 'Temperature': 24.3, 'Humidity': 42.68, 'Wind_Speed': 4.09, 'Avg_Past_Consumption': 2.94, 'Consumption_Diff': 0.03}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 9.92, 'Temperature': 25.85, 'Humidity': 66.59, 'Wind_Speed': 4.94, 'Avg_Past_Consumption': 3.28, 'Consumption_Diff': 6.64}
# 📌 Status: 🚨 ANOMALY
# ⚙️ Action: Send Alert
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.32, 'Temperature': 32.25, 'Humidity': 50.72, 'Wind_Speed': 8.37, 'Avg_Past_Consumption': 3.44, 'Consumption_Diff': -0.12}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.42, 'Temperature': 24.62, 'Humidity': 67.55, 'Wind_Speed': 1.98, 'Avg_Past_Consumption': 3.97, 'Consumption_Diff': -1.55}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.22, 'Temperature': 32.49, 'Humidity': 38.34, 'Wind_Speed': 4.45, 'Avg_Past_Consumption': 2.21, 'Consumption_Diff': 1.01}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 6.14, 'Temperature': 29.02, 'Humidity': 41.29, 'Wind_Speed': 5.56, 'Avg_Past_Consumption': 2.58, 'Consumption_Diff': 3.55}
# 📌 Status: ⚠️ Suspicious
# ⚙️ Action: Monitor
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.51, 'Temperature': 31.76, 'Humidity': 63.78, 'Wind_Speed': 0.91, 'Avg_Past_Consumption': 3.62, 'Consumption_Diff': -0.11}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.39, 'Temperature': 32.8, 'Humidity': 41.36, 'Wind_Speed': 7.48, 'Avg_Past_Consumption': 2.73, 'Consumption_Diff': -0.34}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 2.82, 'Temperature': 20.59, 'Humidity': 64.99, 'Wind_Speed': 0.7, 'Avg_Past_Consumption': 2.69, 'Consumption_Diff': 0.13}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.1, 'Temperature': 27.51, 'Humidity': 62.26, 'Wind_Speed': 0.45, 'Avg_Past_Consumption': 2.28, 'Consumption_Diff': 0.83}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.77, 'Temperature': 20.4, 'Humidity': 37.51, 'Wind_Speed': 3.01, 'Avg_Past_Consumption': 3.06, 'Consumption_Diff': 0.71}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.49, 'Temperature': 27.27, 'Humidity': 59.79, 'Wind_Speed': 7.42, 'Avg_Past_Consumption': 2.34, 'Consumption_Diff': 1.15}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.33, 'Temperature': 27.51, 'Humidity': 33.49, 'Wind_Speed': 7.64, 'Avg_Past_Consumption': 3.28, 'Consumption_Diff': 0.06}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.63, 'Temperature': 29.23, 'Humidity': 57.82, 'Wind_Speed': 6.57, 'Avg_Past_Consumption': 2.22, 'Consumption_Diff': 1.41}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.16, 'Temperature': 25.82, 'Humidity': 65.83, 'Wind_Speed': 9.79, 'Avg_Past_Consumption': 2.02, 'Consumption_Diff': 1.14}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# =========================
# 📊 Sample Data: {'Electricity_Consumed': 3.79, 'Temperature': 34.4, 'Humidity': 40.66, 'Wind_Speed': 0.22, 'Avg_Past_Consumption': 3.61, 'Consumption_Diff': 0.18}
# 📌 Status: ✅ Normal
# ⚙️ Action: No Action
# =========================
#
# 🛑 Simulation Stopped by User

# %%
import random
import time

def generate_sample():
    """Generate a single smart meter reading"""

    consumption = random.uniform(2, 4)

    # simulate occasional anomaly spikes
    if random.random() < 0.1:
        consumption = random.uniform(6, 10)

    temperature = random.uniform(20, 35)
    humidity = random.uniform(30, 70)
    wind_speed = random.uniform(0, 10)
    avg_past = random.uniform(2, 4)

    consumption_diff = consumption - avg_past

    return {
        'Electricity_Consumed': round(consumption, 2),
        'Temperature': round(temperature, 2),
        'Humidity': round(humidity, 2),
        'Wind_Speed': round(wind_speed, 2),
        'Avg_Past_Consumption': round(avg_past, 2),
        'Consumption_Diff': round(consumption_diff, 2)
    }


# simulation control flag
running = True

print("⚡ Smart Meter Simulation Started (Press CTRL + C to stop)\n")

try:
    step = 1

    while running:

        sample = generate_sample()

        # simple intelligent rule layer (light expert system logic)
        consumption = sample["Electricity_Consumed"]

        if consumption >= 7:
            status = "CRITICAL ANOMALY"
            action = "🚨 Immediate Alert Sent"
            color = "RED"

        elif consumption >= 5:
            status = "SUSPICIOUS ACTIVITY"
            action = "⚠️ Monitoring Activated"
            color = "ORANGE"

        else:
            status = "NORMAL OPERATION"
            action = "✅ No Action Required"
            color = "GREEN"

        # display output
        print(f"\n--- Reading #{step} ---")
        print("Data:", sample)
        print("Status:", status)
        print("Action:", action)

        step += 1

        time.sleep(1)

except KeyboardInterrupt:
    running = False
    print("\n🛑 Simulation Stopped Successfully by User")
# Out:
# ⚡ Smart Meter Simulation Started (Press CTRL + C to stop)
#
#
# --- Reading #1 ---
# Data: {'Electricity_Consumed': 9.52, 'Temperature': 31.76, 'Humidity': 46.45, 'Wind_Speed': 9.04, 'Avg_Past_Consumption': 3.25, 'Consumption_Diff': 6.27}
# Status: CRITICAL ANOMALY
# Action: 🚨 Immediate Alert Sent
#
# --- Reading #2 ---
# Data: {'Electricity_Consumed': 2.58, 'Temperature': 30.65, 'Humidity': 30.76, 'Wind_Speed': 7.38, 'Avg_Past_Consumption': 3.03, 'Consumption_Diff': -0.46}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #3 ---
# Data: {'Electricity_Consumed': 2.18, 'Temperature': 29.45, 'Humidity': 64.71, 'Wind_Speed': 1.64, 'Avg_Past_Consumption': 3.57, 'Consumption_Diff': -1.4}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #4 ---
# Data: {'Electricity_Consumed': 3.49, 'Temperature': 22.23, 'Humidity': 43.1, 'Wind_Speed': 9.42, 'Avg_Past_Consumption': 3.07, 'Consumption_Diff': 0.42}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #5 ---
# Data: {'Electricity_Consumed': 3.49, 'Temperature': 20.72, 'Humidity': 63.21, 'Wind_Speed': 2.93, 'Avg_Past_Consumption': 3.3, 'Consumption_Diff': 0.2}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #6 ---
# Data: {'Electricity_Consumed': 2.82, 'Temperature': 34.35, 'Humidity': 45.05, 'Wind_Speed': 3.66, 'Avg_Past_Consumption': 2.25, 'Consumption_Diff': 0.57}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #7 ---
# Data: {'Electricity_Consumed': 2.08, 'Temperature': 23.69, 'Humidity': 65.17, 'Wind_Speed': 3.76, 'Avg_Past_Consumption': 2.84, 'Consumption_Diff': -0.76}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #8 ---
# Data: {'Electricity_Consumed': 3.79, 'Temperature': 22.33, 'Humidity': 60.29, 'Wind_Speed': 0.17, 'Avg_Past_Consumption': 2.59, 'Consumption_Diff': 1.2}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #9 ---
# Data: {'Electricity_Consumed': 3.4, 'Temperature': 22.9, 'Humidity': 65.39, 'Wind_Speed': 8.38, 'Avg_Past_Consumption': 3.6, 'Consumption_Diff': -0.2}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #10 ---
# Data: {'Electricity_Consumed': 2.26, 'Temperature': 29.39, 'Humidity': 51.47, 'Wind_Speed': 6.04, 'Avg_Past_Consumption': 2.57, 'Consumption_Diff': -0.31}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #11 ---
# Data: {'Electricity_Consumed': 2.54, 'Temperature': 21.04, 'Humidity': 49.49, 'Wind_Speed': 0.25, 'Avg_Past_Consumption': 2.12, 'Consumption_Diff': 0.41}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #12 ---
# Data: {'Electricity_Consumed': 3.98, 'Temperature': 22.26, 'Humidity': 35.19, 'Wind_Speed': 6.84, 'Avg_Past_Consumption': 3.4, 'Consumption_Diff': 0.58}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #13 ---
# Data: {'Electricity_Consumed': 2.95, 'Temperature': 25.48, 'Humidity': 65.63, 'Wind_Speed': 5.84, 'Avg_Past_Consumption': 3.14, 'Consumption_Diff': -0.18}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #14 ---
# Data: {'Electricity_Consumed': 2.61, 'Temperature': 24.44, 'Humidity': 64.16, 'Wind_Speed': 8.25, 'Avg_Past_Consumption': 3.5, 'Consumption_Diff': -0.89}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# --- Reading #15 ---
# Data: {'Electricity_Consumed': 8.22, 'Temperature': 22.32, 'Humidity': 64.06, 'Wind_Speed': 6.29, 'Avg_Past_Consumption': 3.07, 'Consumption_Diff': 5.15}
# Status: CRITICAL ANOMALY
# Action: 🚨 Immediate Alert Sent
#
# --- Reading #16 ---
# Data: {'Electricity_Consumed': 2.23, 'Temperature': 32.09, 'Humidity': 51.21, 'Wind_Speed': 9.89, 'Avg_Past_Consumption': 2.41, 'Consumption_Diff': -0.18}
# Status: NORMAL OPERATION
# Action: ✅ No Action Required
#
# 🛑 Simulation Stopped Successfully by User

# %%
# !pip install qrcode[pil]
# Out:
# Collecting qrcode[pil]
#   Downloading qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pillow>=9.1.0 in /usr/local/lib/python3.12/dist-packages (from qrcode[pil]) (11.3.0)
# Downloading qrcode-8.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: qrcode
# Successfully installed qrcode-8.2

# %%
import qrcode
from IPython.display import display

# Link you want inside the QR code
data = "https://colab.research.google.com/drive/1u-U4dO1-nkm4pr1GY7i7P3vVaPQ9ZJKO"

# Create QR code
qr = qrcode.make(data)

# Display QR code
display(qr)

# Save QR code image
qr.save("powerguard_qr.png")
